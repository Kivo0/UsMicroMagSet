# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib_inline
import pandas as pd

# %%
import USMMgSt
import importlib
importlib.reload(USMMgSt)
# Out:
# <module 'USMMgSt' from 'g:\\deeplearning\\dataset_tracking\\DatasetBackup\\USMMgSt.py'>

# %%
labels , images = USMMgSt.readrobot("cube",3)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i],labels.iloc[i][1:5])

# %%
labels , images = USMMgSt.readrobot("helical",1)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i],labels.iloc[i][1:5])

# %%
labels , images = USMMgSt.readrobot("cylinder",3)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i],labels.iloc[i][1:5])

# %%
labels , images = USMMgSt.readrobot("rollingcube",3)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i],labels.iloc[i][1:5])

# %%
labels , images = USMMgSt.readrobot("flagella",3)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i],labels.iloc[i][1:5])

# %%
labels , images = USMMgSt.readrobot("sheetrobot",3)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i],labels.iloc[i][1:5])

# %%
import USMMgSt
import importlib
importlib.reload(USMMgSt)
# Out:
# <module 'USMMgSt' from 'g:\\deeplearning\\dataset_tracking\\DatasetBackup\\USMMgSt.py'>

# %%
labels , images = USMMgSt.readrobot("sphere3",3)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i],labels.iloc[i][1:5])

# %%
labels , images = USMMgSt.readrobot("sphere1",3)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(40,20))
for a in ax.ravel():
    a.axis('off')

for i in range(1,7):
    plt.subplot(2, 3, i)
   
    USMMgSt.plotimage_withbbox(images[i+2],labels.iloc[i+5][1:5])

# %%
# !jupyter nbconvert --ClearMetadataPreprocessor.enabled=True --ClearOutput.enabled=True --to markdown README.ipynb
# Out:
# [NbConvertApp] Converting notebook README.ipynb to markdown
# [NbConvertApp] Support files will be in README_files\
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Making directory README_files
# [NbConvertApp] Writing 3281 bytes to README.md
